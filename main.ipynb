# %%
import pandas as pd

# %%
df = pd.read_csv("./dataset.csv", delimiter=';')

# %%
df
# Out:
#                                                    URL  Unnamed: 0  \
# 0         https://github.com/claranet/spryker-demoshop           4
# 1                    https://github.com/nocproject/noc          13
# 2              https://github.com/MaharaProject/mahara          15
# 3                    https://github.com/mirumee/saleor          17
# 4                https://github.com/cfpb/hmda-platform          18
# ..                                                 ...         ...
# 373        https://github.com/avi202020/fx-trading-app        3736
# 374  https://github.com/atulmy/fullstack-javascript...        3749
# 375          https://github.com/abixen/abixen-platform        3779
# 376        https://github.com/apache/skywalking-nodejs        3790
# 377         https://github.com/andreybavt/Hobo-Sapiens        3802
#
#                                    Identifier  \
# 0                   claranet/spryker-demoshop
# 1                              nocproject/noc
# ...
