# %%
import json

# %%
with open('closed_issues_milvus-io_milvus.json', 'r') as file:
    data = json.load(file)

# %%
len(data)
# Out:
# 33218

# %%
data[0]
# Out:
# {'url': 'https://api.github.com/repos/milvus-io/milvus/issues/36208',
#  'repository_url': 'https://api.github.com/repos/milvus-io/milvus',
#  'labels_url': 'https://api.github.com/repos/milvus-io/milvus/issues/36208/labels{/name}',
#  'comments_url': 'https://api.github.com/repos/milvus-io/milvus/issues/36208/comments',
#  'events_url': 'https://api.github.com/repos/milvus-io/milvus/issues/36208/events',
#  'html_url': 'https://github.com/milvus-io/milvus/pull/36208',
#  'id': 2521825169,
#  'node_id': 'PR_kwDODHDyxM57Rgd_',
#  'number': 36208,
#  'title': 'enhance: [2.4] Add L0 forward policy to support remote load (#36189)',
#  'user': {'login': 'congqixia',
#   'id': 84113973,
#   'node_id': 'MDQ6VXNlcjg0MTEzOTcz',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/84113973?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/congqixia',
#   'html_url': 'https://github.com/congqixia',
# ...
